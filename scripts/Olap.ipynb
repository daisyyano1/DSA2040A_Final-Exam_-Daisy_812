# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# Connect to your data warehouse
conn = sqlite3.connect(r"C:\Users\USER\OneDrive\Desktop\Data Warehousing\DSA204 final Exam\retail_dw.db")

# %% [markdown]
# #clustering_iris Report
